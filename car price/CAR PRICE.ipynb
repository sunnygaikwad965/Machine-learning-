# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\KING\\Desktop\\CarPrice_Assignment.csv')
df.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
newdf = df.select_dtypes(include=np.number)
newdf
# Out:
#      car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0         1          3       88.6      168.8      64.1       48.8        2548
# 1         2          3       88.6      168.8      64.1       48.8        2548
# 2         3          1       94.5      171.2      65.5       52.4        2823
# 3         4          2       99.8      176.6      66.2       54.3        2337
# 4         5          2       99.4      176.6      66.4       54.3        2824
# ..      ...        ...        ...        ...       ...        ...         ...
# 200     201         -1      109.1      188.8      68.9       55.5        2952
# 201     202         -1      109.1      188.8      68.8       55.5        3049
# 202     203         -1      109.1      188.8      68.9       55.5        3012
# 203     204         -1      109.1      188.8      68.9       55.5        3217
# 204     205         -1      109.1      188.8      68.9       55.5        3062
#
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# ## No missing values were present in the dataset

# %%
import seaborn as sns

# %% [markdown]
# ## Exploratory data analysis

# %%
count = df["CarName"].value_counts()
print(count)
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64

# %% [markdown]
# ## Fuel Type :-

# %%
count = df["fueltype"].value_counts()
print(count)
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
sns.countplot(x="fueltype",data=df,color="orange")
# Out:
# <AxesSubplot:xlabel='fueltype', ylabel='count'>

# %% [markdown]
# ## In this dataset more than 185 cars used as Gas fuel type
# ## In this dataset range of 20-30 cars used as Diesel fuel type

# %% [markdown]
# ## Engine Location

# %%
count = df["enginelocation"].value_counts()
print(count)
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
sns.countplot(x="enginelocation",data=df,color="yellow")
# Out:
# <AxesSubplot:xlabel='enginelocation', ylabel='count'>

# %% [markdown]
# ## Around 202 cars have engines located at front
# ## Around 3 cars or  A very less no of cars have engines located at rear

# %%
sns.set(style="darkgrid")
sns.distplot(df["price"], color="blue")
plt.show()
# Out:
# C:\Users\KING\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10120/2204762959.py in <module>
#       1 sns.set(style="darkgrid")
#       2 sns.distplot(df["price"], color="blue")
# ----> 3 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Door number

# %%
count = df["doornumber"].value_counts()
print(count)
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
plt.figure(figsize= (7,7))
plot = count.plot.pie(y="doornumber")
plt.xticks(fontsize = 7)
plt.yticks(fontsize = 7)
plt.legend()
plt.show()

# %% [markdown]
# ## Out of 205 cars
# ## 1) 115 cars have four doors
# ## 2) 90 cars have two doors

# %% [markdown]
# ## Aspiration

# %%
count = df["aspiration"].value_counts()
print(count)
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
sns.countplot(x="aspiration",data=df)
# Out:
# <AxesSubplot:xlabel='aspiration', ylabel='count'>

# %% [markdown]
# ## Out of 205 cars
# ## 1) 168 cars have std aspiration
# ## 2) 37 cars have turbo aspiration

# %% [markdown]
# ## Wheeldrive

# %%
count = df["drivewheel"].value_counts()
print(count)
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
sns.countplot(x="drivewheel",data=df)
# Out:
# <AxesSubplot:xlabel='drivewheel', ylabel='count'>

# %% [markdown]
# ### Out of 205 cars
# ### 1) 9 cars have four drive wheel
# ### 2) 76 cars have rear drive wheel
# ### 3) 120 cars have forward drive wheel
#
# ###  Out of 205 cars 120 cars have forward drive wheel

# %% [markdown]
# # Car Body Types

# %%
count = df["carbody"].value_counts()
print(count)
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
plt.figure(figsize= (7,7))
plot = count.plot.pie(y="carbody")
plt.xticks(fontsize = 7)
plt.yticks(fontsize = 7)
plt.legend()
plt.show()

# %%
sns.countplot(x="carbody",data=df)
# Out:
# <AxesSubplot:xlabel='carbody', ylabel='count'>

# %% [markdown]
# ###  out of 205 cars
# ### 1) 96 cars have sedan carbody
# ### 2) 70 cars have hatchback carbody
# ### 3) 25 cars have wagon carbody
# ### 4) 8 cars have hardtop carbody
# ### 5) 6 cars hve convertible carbody
#
# ### Most cars have sedan carbody

# %% [markdown]
# # Fuel system

# %%
count = df["fuelsystem"].value_counts()
print(count)
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
plt.figure(figsize = (5,5))
plot = count.plot.pie(y = "fuelsystem")
plt.legend()
plt.show()

# %% [markdown]
# ### Around 45% cars having mpfi fuelsystem

# %% [markdown]
# ### Symboling

# %%
count = df["symboling"].value_counts()
print(count)
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
sns.countplot(x="symboling",data=df)
# Out:
# <AxesSubplot:xlabel='symboling', ylabel='count'>

# %% [markdown]
# ### Around 67 cars having 0 symboling means risk factor is correctly considered with its price
# ### Around 3 cars have -2 symboling means risk is high compared to its price

# %% [markdown]
# # Comparison

# %% [markdown]
# ### Fuelsystem vs Price

# %%
sns.boxplot(x="fuelsystem",y="price",data=df)
plt.show()

# %% [markdown]
# ### By considering comparison of fuel system idi fuelsystem car rates are higher than mpfi fuelsystem cars

# %% [markdown]
# ### Drivewheel vs Price

# %%
sns.boxplot(x="drivewheel",y="price",data=df)
plt.show()

# %% [markdown]
# ### By considering  comparison of drivewheel system  rear drivewheel cars are more costlier than compared to forward drivewheel and four wheel drive

# %% [markdown]
# ### CarBody vs price

# %%
sns.boxplot(x="carbody",y="price",data=df)
# Out:
# <AxesSubplot:xlabel='carbody', ylabel='price'>

# %% [markdown]
# ### By considering  comparison of Bodytype hardtop cars are higher compared to other body cars

# %% [markdown]
# # Symbol vs price

# %%
sns.boxplot(x="symboling",y="price",data=df)
# Out:
# <AxesSubplot:xlabel='symboling', ylabel='price'>

# %% [markdown]
# ### cars having -1 symbooling are ranging between 15k-25k

# %% [markdown]
# # Hp vs price

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x="horsepower",y="price",data=df, kind="hex")

# %% [markdown]
# # Enginesize vs price

# %%
plt.figure(figsize =(10,10))
sns.jointplot(x="enginesize",y="price",data=df,kind="hex")

# %%
newdf
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0            3       88.6      168.8      64.1       48.8        2548
# 1            3       88.6      168.8      64.1       48.8        2548
# 2            1       94.5      171.2      65.5       52.4        2823
# 3            2       99.8      176.6      66.2       54.3        2337
# 4            2       99.4      176.6      66.4       54.3        2824
# ..         ...        ...        ...       ...        ...         ...
# 200         -1      109.1      188.8      68.9       55.5        2952
# 201         -1      109.1      188.8      68.8       55.5        3049
# 202         -1      109.1      188.8      68.9       55.5        3012
# 203         -1      109.1      188.8      68.9       55.5        3217
# 204         -1      109.1      188.8      68.9       55.5        3062
#
#      enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# ...

# %%
newdf.corr()
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# ...

# %% [markdown]
# ### Heat map of Numeric columns

# %%
plt.figure(figsize=(10,10))
sns.heatmap(newdf.corr(),annot=True,cmap="RdBu")
plt.show()

# %% [markdown]
# ### Darker the blue color more is the positive correlation.
# ### Darker the red color more is the negative correlation.

# %% [markdown]
# # we have done EDA on car price prediction considering various factors affecting the price
